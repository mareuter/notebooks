# %%
import numpy as np
from matplotlib import pyplot as plt
plt.ion()
#%matplotlib inline

# %%
from lsst.daf.persistence import Butler

# %%
butler = Butler('/home/shared/twinkles/output_data_v2')
subset = butler.subset('src', filter='r')

# %%
subset.cache[0]
# Out:
# {'filter': 'r', 'raft': '2,2', 'sensor': '1,1', 'visit': 230}

# %%
calexp = butler.get('calexp', **subset.cache[0])
src = butler.get('src', **subset.cache[0])

# %%
plt.figure(figsize=(8, 8))
plt.imshow(calexp.getImage().array, 
           vmin=np.percentile(calexp.getImage().array, 10), 
           vmax=np.percentile(calexp.getImage().array, 90), cmap='gray')
plt.colorbar()
plt.scatter(src.getX(), src.getY(), c='red', s=2)

# %%
len(src)
# Out:
# 2613
