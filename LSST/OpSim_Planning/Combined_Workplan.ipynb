# %%
# Doing by file until I can figure out OAuth
import os
token_file = os.path.join(os.path.expanduser("~/"), ".jira_auth")
with open(token_file, 'r') as fd:
    uname = fd.readline().strip()  # Can't hurt to be paranoid
    pwd = fd.readline().strip()

SERVER = "https://jira.lsstcorp.org/"
from jira import JIRA
js = JIRA(server=SERVER, basic_auth=(uname, pwd))

# %%
query = "project = Simulations AND issuetype = Epic AND summary ~ \"SOCS Release\" ORDER BY key"
issues = js.search_issues(query)
print len(issues)
# Out:
# 12

# %%
def get_linked_epics(issue, linkTypeName="Containment"):
    linked_epics = []
    links = issue.fields.issuelinks
    for link in links:
        if link.type.name == linkTypeName:
            linked_epics.append(js.issue(link.outwardIssue.key))
    return linked_epics

# %%
def get_component(istr):
    return istr.split()[0]

# %%
def create_list_from_numbered_description(desrc, bulletType="*"):
    import re
    olist = []
    for line in desrc.strip().split(os.linesep):
        values = line.split()
        if re.match("\d+\.\d+", values[0]) is None:
            numbered = bulletType
        else:
            if USE_MARKDOWN:
                numbered = " " * 2 + bulletType
            else:
                numbered = bulletType * 2
        olist.append("{0} {1}".format(numbered, " ".join(values[1:])))
    return olist

# %%
USE_MARKDOWN = True
# Write some boiler plate for the page
page_content = []
import time
page_content.append("This page provides the coordinated work plan between the Simulated OCS (SOCS) and the Scheduler.")
if USE_MARKDOWN:
    page_content.append("")
page_content.append("Updated: {0}".format(time.strftime("%Y-%m-%d %H:%M", time.localtime())))
page_content.append("")

# %%
for issue in issues:
    socs_summary = issue.fields.summary
    version = socs_summary.split()[-1]
    if USE_MARKDOWN:
        page_content.append("## Combined Release {0}".format(version))
    else:
        page_content.append("h2. Combined Release {0}".format(version))
    #print issue.fields.summary
    socs_descr = issue.fields.description
    comb_duedate = issue.fields.duedate
    if USE_MARKDOWN:
        page_content.append("**Release Date:** {0}".format(comb_duedate))
    else:
        page_content.append("*Release Date:* {0}".format(comb_duedate))
    page_content.append("")
    #sub_epics = get_linked_epics(issue)

    if USE_MARKDOWN:
        socs_work = create_list_from_numbered_description(socs_descr, "1.")
    else:
        socs_work = create_list_from_numbered_description(socs_descr)
    
    # Should only be one!
    sched_epic = get_linked_epics(issue, "Relates")[0]
    sched_summary = sched_epic.fields.summary
    sched_descr = sched_epic.fields.description
    if USE_MARKDOWN:
        sched_work = create_list_from_numbered_description(sched_descr, "1.")
    else:
        sched_work = create_list_from_numbered_description(sched_descr)
    
    # Create Table 
    if USE_MARKDOWN:
        page_content.append("{0} Workplan | {1} Workplan".format(socs_summary.split()[0], sched_summary.split()[0]))
        page_content.append("--- | ---")
    else:
        page_content.append("|| {0} Workplan || {1} Workplan ||".format(socs_summary.split()[0], sched_summary.split()[0]))
    
    if not USE_MARKDOWN:
        page_content.append("| {0} | {1} |".format(os.linesep.join(socs_work), os.linesep.join(sched_work)))
    else:    
        import itertools
        for ssw, sdw in itertools.izip_longest(socs_work, sched_work, fillvalue=" "):
            page_content.append("{0} | {1}".format(ssw, sdw))
                        
    page_content.append("")
    page_content.append("")

if USE_MARKDOWN:
    import markdown
    html = markdown.markdown(os.linesep.join(page_content), output_format="html5",
                            extensions=["markdown.extensions.extra"])
    print html
    import codecs
    output_file = codecs.open("combined_workplan.html", "w", encoding="utf-8", errors="xmlcharrefreplace")
    output_file.write(html)
else:
    print os.linesep.join(page_content)
# Out:
# This page provides the coordinated work plan between the Simulated OCS (SOCS) and the Scheduler.
#
# Updated: 2015-07-28 21:55
#
# ## Combined Release v0.1
# **Release Date:** 2015-07-31
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Release OpSim Requirements document
# 1. Design SOCS independant of OpSim
# 1. Define and initiate SOCS code modules in SE Simulations repository
# 1. Prototype and benchmark Communications using current release of DDS-SAL-Python | 1. Release Scheduler Interface Document
# 1. Design Scheduler independent from OpSim
# 1. Define and initiate Scheduler code modules in T&S repository
# 1. Prototype and benchmark Communications using current release of DDS-SAL-Python |
#
#
# ## Combined Release v0.2
# **Release Date:** 2015-10-30
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Implement SOCS structure with interface
# 1. Implement simulation kernel with time simulator
# 1. Refactor and integrate observatory model
# 1. Implement observatory telemetry simulator
# 1. Implement simulation sequencer with targets handling
# 1. Refactor and integrate observations DB
# 1. Integrate with Scheduler
#   1. SOCS topics: telemetry for time and observatory conditions
#   1. Scheduler topics: next target from scripted proposal | 1. Implement Scheduler structure with interface
# 1. Implement time handling
# 1. Refactor and integrate observatory model
# 1. Implement Scripted Proposal
# 1. Integrate with simulator (SOCS)
#   1. SOCS topics: telemetry for time and observatory conditions
#   1. Scheduler topics: next target from scripted proposal |
#
#
# ## Combined Release v0.3
# **Release Date:** 2016-01-29
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Refactor and integrate Astronomical Sky
# 1. Integrate Observatory Model slew and track behavior for observing visits
# 1. Implement observing behavior in simulation sequencer
# 1. Integrate DB storage of targets received and visits performed
# 1. Integrate and benchmark performance with Scheduler
#   1. Test multiple AD proposals survey with slew time cost and sky brightness
#   1. Test repeatability
#   1. Test speed under simulation | 1. Refactor and integrate Astronomical Sky
# 1. Integrate Observatory Model slew time estimations
# 1. Implement Survey Driver with slew time cost
# 1. Refactor and integrate Area Distribution Science Proposals
# 1. Integrate and benchmark performance with SOCS
#   1. Test multiple AD proposals survey with slew time cost and sky brightness
#   1. Test repeatability
#   1. Test speed under simulation |
#
#
# ## Combined Release v1.0
# **Release Date:** 2016-04-29
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Refactor and integrate Environment Model
# 1. Simulate weather telemetry, clouds and seeing
# 1. Incorporate filter swaps during new moon
# 1. Incorporate downtime simulator
# 1. Implement Scheduler configuration via commands
# 1. Integrate with Scheduler
#   1. Test with complete survey
#   1. Test repeatability
#   1. Test execution speed | 1. Refactor and integrate Time Distribution Science Proposals
# 1. Incorporate filter swaps during new moon
# 1. Implement inter-proposal self balancing priority
# 1. Incorporate weather telemetry handling
# 1. Integrate with SOCS
#   1. Test with complete survey
#   1. Test repeatability
#   1. Test execution speed |
#
#
# ## Combined Release v1.1
# **Release Date:** 2016-07-29
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Support Development for Area Distribution Look Ahead in Scheduler 1.1
# 1. Implement non deterministic weather simulator
# 1. Implement non deterministic downtime simulator
# 1. Integrate and test with SOCS
#   1. Test survey with Area Distribution proposals and Look Ahead
#   1. Test speed performance
#   1. Test repeatability | 1. Implement deterministic look ahead data structure
# 1. Implement Look Ahead algorithm for Area Distribution Proposals
# 1. Integrate and test with SOCS
#   1. Test survey with Area Distribution proposals and Look Ahead
#   1. Test speed performance
#   1. Test repeatability |
#
#
# ## Combined Release v1.2
# **Release Date:** 2016-10-28
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Support Tests for Area Distribution Look Ahead in Scheduler 1.1
# 1. Support Development for Time Distribution Look Ahead in Scheduler 1.2 | 1. Implement Look Ahead algorithm for Time Distribution Proposals
# 1. Integrate and test with SOCS
#   1. Validate Sequences selection with look ahead
#   1. Test speed performance |
#
#
# ## Combined Release v1.3
# **Release Date:** 2017-01-27
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Evaluate and implement performance enhancements | 1. Implement warm start capability
# 1. Implement image quality feedback handling
# 1. Implement degraded operational modes
#   1. Constrained limits and/or speeds for mount, rotator, dome, optics.
#   1. Constrained availability of filters
# 1. Integrate and test with SOCS
#   1. Test resuming partial surveys
#   1. Test variable image quality feedback
#   1. Test degraded modes |
#
#
# ## Combined Release v1.4
# **Release Date:** 2017-04-28
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Implement warm start DB interface for Scheduler
# 1. Implement image quality feedback simulator
# 1. Implement degraded operational modes simulator
#   1. Constrained limits and/or speeds for mount, rotator, dome, optics.
#   1. Constrained availability of filters
# 1. Integrate and test with Scheduler
#   1. Test resuming partial surveys
#   1. Test variable image quality feedback
#   1. Test degraded modes | 1. Implement warm start capability
# 1. Implement image quality feedback handling
# 1. Implement degraded operational modes
#   1. Constrained limits and/or speeds for mount, rotator, dome, optics.
#   1. Constrained availability of filters
# 1. Integrate and test with SOCS
#   1. Test resuming partial surveys
#   1. Test variable image quality feedback
#   1. Test degraded modes |
#
#
# ## Combined Release v1.5
# **Release Date:** 2017-07-28
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Implement spatial distribution for weather simulator
# 1. Integrate and test with Scheduler
#   1. Test dithering in Scheduler
#   1. Test spatial distribution for weather in a survey | 1. Implement Dithering algorithm
# 1. Implement handling of spatial distribution for weather telemetry
# 1. Integrate and test with SOCS |
#
#
# ## Combined Release v2.0
# **Release Date:** 2017-10-27
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Support Scheduler Implementation for publication of future targets schedule
# 1. Integrate and test with SOCS | 1. Implement publication of future targets schedule
# 1. Integrate and test with SOCS |
#
#
# ## Combined Release v2.1
# **Release Date:** 2018-01-26
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Implement weather forecast
# 1. Integrate and test with Scheduler | 1. Implement handling of weather forecast in look ahead algorithms
# 1. Integrate and test with SOCS |
#
#
# ## Combined Release v2.2
# **Release Date:** 2018-04-27
#
# SOCS Workplan | Scheduler Workplan
# --- | ---
# | 1. Support Scheduler implementation of generic interface for optimization algorithms
# 1. Support Schedule Incorporation community provided optimizations | 1. Implement generic interface for optimization algorithms
# 1. Incorporate community provided optimizations |
#
#
# <p>This page provides the coordinated work plan between the Simulated OCS (SOCS) and the Scheduler.</p>
# <p>Updated: 2015-07-28 21:55</p>
# <h2>Combined Release v0.1</h2>
# <p><strong>Release Date:</strong> 2015-07-31</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Release OpSim Requirements document</td>
# </tr>
# <tr>
# <td>1. Design SOCS independant of OpSim</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Define and initiate SOCS code modules in SE Simulations repository</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Prototype and benchmark Communications using current release of DDS-SAL-Python</td>
# <td>1. Release Scheduler Interface Document</td>
# </tr>
# <tr>
# <td>1. Design Scheduler independent from OpSim</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Define and initiate Scheduler code modules in T&amp;S repository</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Prototype and benchmark Communications using current release of DDS-SAL-Python</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v0.2</h2>
# <p><strong>Release Date:</strong> 2015-10-30</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Implement SOCS structure with interface</td>
# </tr>
# <tr>
# <td>1. Implement simulation kernel with time simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Refactor and integrate observatory model</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement observatory telemetry simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement simulation sequencer with targets handling</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Refactor and integrate observations DB</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate with Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. SOCS topics: telemetry for time and observatory conditions</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Scheduler topics: next target from scripted proposal</td>
# <td>1. Implement Scheduler structure with interface</td>
# </tr>
# <tr>
# <td>1. Implement time handling</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Refactor and integrate observatory model</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement Scripted Proposal</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate with simulator (SOCS)</td>
# <td></td>
# </tr>
# <tr>
# <td>1. SOCS topics: telemetry for time and observatory conditions</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Scheduler topics: next target from scripted proposal</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v0.3</h2>
# <p><strong>Release Date:</strong> 2016-01-29</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Refactor and integrate Astronomical Sky</td>
# </tr>
# <tr>
# <td>1. Integrate Observatory Model slew and track behavior for observing visits</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement observing behavior in simulation sequencer</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate DB storage of targets received and visits performed</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and benchmark performance with Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test multiple AD proposals survey with slew time cost and sky brightness</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test speed under simulation</td>
# <td>1. Refactor and integrate Astronomical Sky</td>
# </tr>
# <tr>
# <td>1. Integrate Observatory Model slew time estimations</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement Survey Driver with slew time cost</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Refactor and integrate Area Distribution Science Proposals</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and benchmark performance with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test multiple AD proposals survey with slew time cost and sky brightness</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test speed under simulation</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.0</h2>
# <p><strong>Release Date:</strong> 2016-04-29</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Refactor and integrate Environment Model</td>
# </tr>
# <tr>
# <td>1. Simulate weather telemetry, clouds and seeing</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Incorporate filter swaps during new moon</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Incorporate downtime simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement Scheduler configuration via commands</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate with Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test with complete survey</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test execution speed</td>
# <td>1. Refactor and integrate Time Distribution Science Proposals</td>
# </tr>
# <tr>
# <td>1. Incorporate filter swaps during new moon</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement inter-proposal self balancing priority</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Incorporate weather telemetry handling</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test with complete survey</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test execution speed</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.1</h2>
# <p><strong>Release Date:</strong> 2016-07-29</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Support Development for Area Distribution Look Ahead in Scheduler 1.1</td>
# </tr>
# <tr>
# <td>1. Implement non deterministic weather simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement non deterministic downtime simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test survey with Area Distribution proposals and Look Ahead</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test speed performance</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td>1. Implement deterministic look ahead data structure</td>
# </tr>
# <tr>
# <td>1. Implement Look Ahead algorithm for Area Distribution Proposals</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test survey with Area Distribution proposals and Look Ahead</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test speed performance</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test repeatability</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.2</h2>
# <p><strong>Release Date:</strong> 2016-10-28</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Support Tests for Area Distribution Look Ahead in Scheduler 1.1</td>
# </tr>
# <tr>
# <td>1. Support Development for Time Distribution Look Ahead in Scheduler 1.2</td>
# <td>1. Implement Look Ahead algorithm for Time Distribution Proposals</td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Validate Sequences selection with look ahead</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test speed performance</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.3</h2>
# <p><strong>Release Date:</strong> 2017-01-27</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Evaluate and implement performance enhancements</td>
# </tr>
# <tr>
# <td>1. Implement image quality feedback handling</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement degraded operational modes</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained limits and/or speeds for mount, rotator, dome, optics.</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained availability of filters</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test resuming partial surveys</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test variable image quality feedback</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test degraded modes</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.4</h2>
# <p><strong>Release Date:</strong> 2017-04-28</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Implement warm start DB interface for Scheduler</td>
# </tr>
# <tr>
# <td>1. Implement image quality feedback simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement degraded operational modes simulator</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained limits and/or speeds for mount, rotator, dome, optics.</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained availability of filters</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test resuming partial surveys</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test variable image quality feedback</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test degraded modes</td>
# <td>1. Implement warm start capability</td>
# </tr>
# <tr>
# <td>1. Implement image quality feedback handling</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Implement degraded operational modes</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained limits and/or speeds for mount, rotator, dome, optics.</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Constrained availability of filters</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test resuming partial surveys</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test variable image quality feedback</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test degraded modes</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v1.5</h2>
# <p><strong>Release Date:</strong> 2017-07-28</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Implement spatial distribution for weather simulator</td>
# </tr>
# <tr>
# <td>1. Integrate and test with Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test dithering in Scheduler</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Test spatial distribution for weather in a survey</td>
# <td>1. Implement Dithering algorithm</td>
# </tr>
# <tr>
# <td>1. Implement handling of spatial distribution for weather telemetry</td>
# <td></td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v2.0</h2>
# <p><strong>Release Date:</strong> 2017-10-27</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Support Scheduler Implementation for publication of future targets schedule</td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td>1. Implement publication of future targets schedule</td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v2.1</h2>
# <p><strong>Release Date:</strong> 2018-01-26</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Implement weather forecast</td>
# </tr>
# <tr>
# <td>1. Integrate and test with Scheduler</td>
# <td>1. Implement handling of weather forecast in look ahead algorithms</td>
# </tr>
# <tr>
# <td>1. Integrate and test with SOCS</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <h2>Combined Release v2.2</h2>
# <p><strong>Release Date:</strong> 2018-04-27</p>
# <table>
# <thead>
# <tr>
# <th>SOCS Workplan</th>
# <th>Scheduler Workplan</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td></td>
# <td>1. Support Scheduler implementation of generic interface for optimization algorithms</td>
# </tr>
# <tr>
# <td>1. Support Schedule Incorporation community provided optimizations</td>
# <td>1. Implement generic interface for optimization algorithms</td>
# </tr>
# <tr>
# <td>1. Incorporate community provided optimizations</td>
# <td></td>
# </tr>
# </tbody>
# </table>
