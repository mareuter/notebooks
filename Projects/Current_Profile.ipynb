# %%
import pathlib

import hvplot.pandas
import pandas as pd

# %%
data = pathlib.Path("~/data/ppk-20240302T014438.csv").expanduser()

# %%
df = pd.read_csv(data, index_col=0)

# %%
df.head()

# %%
df["Current(uA)"].mean()

# %%
df.hvplot.line()
